# %% [markdown]
# # PRACTICA 3
# JAVIER SCHWARTZ ÁLVAREZ 147389
# ANTONIO HERMOSILLA MORALES 146002
#
#
# ## JUEGO DE ADIVINANZAS
#
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %% [markdown]
# ##### PISTAS
# 1. Trata obtener un número aleatorio entre el 1 y el 100
# 2. Haz una introducción de tu juego y explica las reglas
# 3. Crea una lista que almacene los intentos.
# 4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
# 5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
import random
secret_number = random.randint(1, 100)
print("Welcome to the Number Guessing Game!")
print("I'm thinking of a number between 1 and 100.")
print("Try to guess it!")
print("\nRules:")
print("1. If your guess is less than 1 or greater than 100, I'll say 'OUT OF BOUNDS'.")
print("2. On your first turn, if you're within 10 of the number, I'll say 'HOT!', otherwise 'COLD!'.")
print("3. In subsequent turns, if you get closer, I'll say 'WARMER!', otherwise 'COLDER!'.")
print("4. When you guess the number, I'll tell you you've won and how many tries it took.")
print("-" * 30)
guesses = []
while True:
    try:
        guess = int(input("Enter your guess (1-100): "))
    except ValueError:
        print("Invalid input. Please enter an integer.")
        continue
    if guess < 1 or guess > 100:
        print("OUT OF BOUNDS")
        continue
    guesses.append(guess)
    if guess == secret_number:
        print(f"Congratulations! You guessed the number in {len(guesses)} attempts!")
        break
    if len(guesses) == 1:
        if abs(secret_number - guess) <= 10:
            print("HOT!")
        else:
            print("COLD!")
    else:
        if abs(secret_number - guess) < abs(secret_number - guesses[-2]):
            print("WARMER!")
        else:
            print("COLDER!")
# Out:
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Try to guess it!
#
# Rules:
# 1. If your guess is less than 1 or greater than 100, I'll say 'OUT OF BOUNDS'.
# 2. On your first turn, if you're within 10 of the number, I'll say 'HOT!', otherwise 'COLD!'.
# 3. In subsequent turns, if you get closer, I'll say 'WARMER!', otherwise 'COLDER!'.
# 4. When you guess the number, I'll tell you you've won and how many tries it took.
# ------------------------------
